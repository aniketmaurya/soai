# %% [markdown]
# # Let's create our classifier to detect Dogs and Cats
#
# ![Cats vs Dogs](https://cdn-images-1.medium.com/max/1600/1*oB3S5yHHhvougJkPXuc8og.gif =550x)
#
#
#
# ---
#
#
#
# I am using **`fastai`** 🔥 library which runs on the top of **`PyTorch`**.
#
#
#
#
# I am using  _`fastai`_ because
#
# 1.   It is super easy.
# 2.   It is fast.
# 3.   It is open-source and very well documented.
# 4.   Literally amazing supportive forum https://forum.fast.ai
# 5.   Rest you'll see soon.

# %% [markdown]
# ### To install `fastai` library to your Colab run the following code.

# %%
# !pip install fastai

# %% [markdown]
# # Now, let's import the module which we're gonna use.

# %%
from fastai.vision import *

# %% [markdown]
# `fastai` has a method to download datasets in a line.

# %%
path = untar_data(URLs.DOGS)
# Out:
# ...
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
# ...

# %% [markdown]
# ### After downloading the dataset
#
# 1.   Define transformations https://docs.fast.ai/vision.transform.html
# 2.   Load the data
# 3.   Normalize the data

# %% [markdown]
# Image augmentation can be used in case we have less amount of data or we are overfitting.
# But it can't be used everytime. 6
#
# ![Cat img augmentation](https://cdn-images-1.medium.com/max/780/1*5RXJ2OlVJp4_sd1XzhK6pQ.png =550x)

# %% [markdown]
# ![Normalize](https://github.com/aniketmaurya/soai/blob/master/pics/Screenshot%20from%202019-03-30%2022-10-02.png?raw=true =750x)
#
# Suppose for _House Price Prediction_ we have **number of bedrooms** and **area of house** then _number of bedrooms_ are generally less than 5 and _area_ can be 100 square metres.
#
# So, the our two attributes have totally different scale. We normalize data to bring it to a similar range.
#
# After normlization, generally all the values lies in range of 0 to 1.

# %%
tfms = get_transforms()
data = ImageDataBunch.from_folder(path, 'train', size=128, ds_tfms=tfms)
data.normalize(imagenet_stats)
# Out:
# ImageDataBunch;
#
# Train: LabelList (23000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# cats,cats,cats,cats,cats
# Path: /root/.fastai/data/dogscats;
#
# Valid: LabelList (2000 items)
# x: ImageList
# Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128),Image (3, 128, 128)
# y: CategoryList
# cats,cats,cats,cats,cats
# Path: /root/.fastai/data/dogscats;
#
# Test: None

# %% [markdown]
# ### Before proceeding further it is always a good practice to visualize your data

# %%
data.show_batch(row=3, figsize=(10,10))

# %% [markdown]
# ## Now we're ready to create our DL model
#
# Since , we creating a CNN we use `fastai`'s method `cnn_learner`

# %%
learn = cnn_learner(data, models.resnet34, metrics = accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:01, 83180156.74it/s]

# %% [markdown]
# ## Let's find our learning rate
#
# #### We all have some learning rate. Right?
#
# #### If we study too fast then we understand the topic initially but after some time don't get anything 😕.
#
# #### If we study too slow then we learn everything but we have to learn before exams 😛
#
# ### There is a term _learning Rate_ in ML/DL which is exactly same.
#
# Let's find the best learning rate for our model.

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=1e-033)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/10 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
# ...

# %% [markdown]
# ## We can plot confusion matrix and see what are those images on which our model didn't work well
#
# https://docs.fast.ai/vision.learner.html#ClassificationInterpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(6,6))

# %%
interp.plot_confusion_matrix()

# %%
img = learn.data.train_ds[0][0]
learn.predict(img)[0]
# Out:
# Category cats

# %% [markdown]
# # How should you get started with AI:
#
# 1.   Learn DL and ML theory on Coursera.org by course by Andrew Ng.
#
# 2.   Learn some DL framework.
#
# 3.   Start practicing.
#
# 4.   Create a project.
#
#
#
#
#
# ---
#
# *   [Link to Andrew Ng's notes](https://drive.google.com/open?id=10ncxhoITEPFhIrX8nAzWA_jo68hOKxLM)
#
# *   [Machine Learning](https://www.coursera.org/learn/machine-learning)
#
# *   [Deep Learning](https://www.coursera.org/specializations/deep-learning)
#
# *   [Fast.ai](https://fast.ai)

# %% [markdown]
# # Contact me 👇
#
#
# #### > 🔗 https://twitter.com/imaniketmaurya
#
# #### > 🔗 https://linkedin.com/in/aniketmaurya
#
# #### > 📧 aniketmaurya.ai@gmail.com
#
#
# # I blog here 👇
#
#
# #### >🔗 https://medium.com/@aniketmaurya
